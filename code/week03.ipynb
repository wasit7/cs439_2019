# %%
import numpy as np

# %%
x=np.arange(0,6*np.pi,0.1)
x.shape
# Out:
# (189,)

# %%
y=np.sin(x)+np.random.randn(x.shape[0])*0.5

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use('ggplot')
plt.plot(x,y,'.b')

# %%
y[y<0]=0
plt.plot(x,y,'.b')

# %%
x=np.array([[1,2,3],[4,5,6]])
y=np.array([[11,12,13],[14,15,16]])

# %%
x*y
# Out:
# array([[11, 24, 39],
#        [56, 75, 96]])

# %%
np.multiply(x,y)
# Out:
# array([[11, 24, 39],
#        [56, 75, 96]])

# %%
x
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
x.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
np.dot(x,y.T)
# Out:
# array([[ 74,  92],
#        [182, 227]])

# %%
x.shape
# Out:
# (2, 3)

# %%
y.T.shape
# Out:
# (3, 2)

# %%
x
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
x+1
# Out:
# array([[2, 3, 4],
#        [5, 6, 7]])

# %%
x*2
# Out:
# array([[ 2,  4,  6],
#        [ 8, 10, 12]])

# %%
# %%sh
# ls
# Out:
# cat.jpg
# littleread.txt
# myrec
# Week01.ipynb
# week02_2.ipynb
# week02.ipynb
# week03.ipynb

# %%
# %matplotlib inline
from skimage import io
x=io.imread('cat.jpg')
io.imshow(x[0:150,0:150])
